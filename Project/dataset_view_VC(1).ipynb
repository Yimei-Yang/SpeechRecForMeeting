# %% [markdown]
# # convert xml to panda
# I mounted my own google drive and use the xml files from there, but they are in the same format as the xml-audio folder in this drive.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Team 6/xml-audio"
# Out:
# Bdb001.A.dialogue-acts.xml  Bmr024.E.dialogue-acts.xml
# Bdb001.B.dialogue-acts.xml  Bmr024.F.dialogue-acts.xml
# Bdb001.C.dialogue-acts.xml  Bmr024.G.dialogue-acts.xml
# Bdb001.D.dialogue-acts.xml  Bmr024.H.dialogue-acts.xml
# Bdb001.E.dialogue-acts.xml  Bmr024.I.dialogue-acts.xml
# Bdb001.F.dialogue-acts.xml  Bmr025.A.dialogue-acts.xml
# Bed002.A.dialogue-acts.xml  Bmr025.B.dialogue-acts.xml
# Bed002.B.dialogue-acts.xml  Bmr025.C.dialogue-acts.xml
# Bed002.C.dialogue-acts.xml  Bmr025.D.dialogue-acts.xml
# Bed002.D.dialogue-acts.xml  Bmr025.E.dialogue-acts.xml
# Bed002.E.dialogue-acts.xml  Bmr025.F.dialogue-acts.xml
# Bed002.F.dialogue-acts.xml  Bmr025.G.dialogue-acts.xml
# Bed003.A.dialogue-acts.xml  Bmr025.H.dialogue-acts.xml
# Bed003.B.dialogue-acts.xml  Bmr026.A.dialogue-acts.xml
# Bed003.C.dialogue-acts.xml  Bmr026.B.dialogue-acts.xml
# Bed003.D.dialogue-acts.xml  Bmr026.C.dialogue-acts.xml
# Bed004.A.dialogue-acts.xml  Bmr026.D.dialogue-acts.xml
# Bed004.B.dialogue-acts.xml  Bmr026.E.dialogue-acts.xml
# Bed004.C.dialogue-acts.xml  Bmr026.F.dialogue-acts.xml
# Bed004.D.dialogue-acts.xml  Bmr027.A.dialogue-acts.xml
# Bed005.A.dialogue-acts.xml  Bmr027.B.dialogue-acts.xml
# Bed005.B.dialogue-acts.xml  Bmr027.C.dialogue-acts.xml
# Bed005.C.dialogue-acts.xml  Bmr027.D.dialogue-acts.xml
# Bed005.D.dialogue-acts.xml  Bmr027.E.dialogue-acts.xml
# Bed005.E.dialogue-acts.xml  Bmr027.F.dialogue-acts.xml
# Bed005.F.dialogue-acts.xml  Bmr027.G.dialogue-acts.xml
# Bed006.A.dialogue-acts.xml  Bmr027.H.dialogue-acts.xml
# Bed006.B.dialogue-acts.xml  Bmr028.A.dialogue-acts.xml
# Bed006.C.dialogue-acts.xml  Bmr028.B.dialogue-acts.xml
# Bed006.D.dialogue-acts.xml  Bmr028.C.dialogue-acts.xml
# Bed006.E.dialogue-acts.xml  Bmr028.D.dialogue-acts.xml
# Bed006.F.dialogue-acts.xml  Bmr028.E.dialogue-acts.xml
# Bed006.G.dialogue-acts.xml  Bmr028.F.dialogue-acts.xml
# Bed008.A.dialogue-acts.xml  Bmr028.H.dialogue-acts.xml
# Bed008.B.dialogue-acts.xml  Bmr028.I.dialogue-acts.xml
# Bed008.C.dialogue-acts.xml  Bmr029.A.dialogue-acts.xml
# Bed008.D.dialogue-acts.xml  Bmr029.B.dialogue-acts.xml
# Bed008.E.dialogue-acts.xml  Bmr029.C.dialogue-acts.xml
# Bed009.A.dialogue-acts.xml  Bmr029.E.dialogue-acts.xml
# Bed009.B.dialogue-acts.xml  Bmr029.F.dialogue-acts.xml
# Bed009.C.dialogue-acts.xml  Bmr030.A.dialogue-acts.xml
# Bed009.D.dialogue-acts.xml  Bmr030.B.dialogue-acts.xml
# Bed009.E.dialogue-acts.xml  Bmr030.C.dialogue-acts.xml
# Bed009.F.dialogue-acts.xml  Bmr030.D.dialogue-acts.xml
# Bed009.G.dialogue-acts.xml  Bmr030.E.dialogue-acts.xml
# Bed010.A.dialogue-acts.xml  Bmr031.A.dialogue-acts.xml
# Bed010.B.dialogue-acts.xml  Bmr031.B.dialogue-acts.xml
# Bed010.C.dialogue-acts.xml  Bmr031.C.dialogue-acts.xml
# Bed010.D.dialogue-acts.xml  Bmr031.D.dialogue-acts.xml
# Bed010.E.dialogue-acts.xml  Bmr031.E.dialogue-acts.xml
# Bed010.F.dialogue-acts.xml  Bmr031.F.dialogue-acts.xml
# Bed010.G.dialogue-acts.xml  Bmr031.G.dialogue-acts.xml
# Bed011.A.dialogue-acts.xml  Bmr031.H.dialogue-acts.xml
# Bed011.B.dialogue-acts.xml  Bmr031.I.dialogue-acts.xml
# Bed011.C.dialogue-acts.xml  Bns001.A.dialogue-acts.xml
# Bed011.D.dialogue-acts.xml  Bns001.B.dialogue-acts.xml
# Bed011.E.dialogue-acts.xml  Bns001.C.dialogue-acts.xml
# Bed011.F.dialogue-acts.xml  Bns001.D.dialogue-acts.xml
# Bed012.A.dialogue-acts.xml  Bns001.E.dialogue-acts.xml
# Bed012.B.dialogue-acts.xml  Bns001.F.dialogue-acts.xml
# Bed012.C.dialogue-acts.xml  Bns001.G.dialogue-acts.xml
# Bed012.D.dialogue-acts.xml  Bns002.A.dialogue-acts.xml
# Bed013.A.dialogue-acts.xml  Bns002.B.dialogue-acts.xml
# Bed013.B.dialogue-acts.xml  Bns002.C.dialogue-acts.xml
# Bed013.C.dialogue-acts.xml  Bns002.D.dialogue-acts.xml
# Bed013.D.dialogue-acts.xml  Bns002.E.dialogue-acts.xml
# Bed013.E.dialogue-acts.xml  Bns003.A.dialogue-acts.xml
# Bed014.A.dialogue-acts.xml  Bns003.B.dialogue-acts.xml
# Bed014.B.dialogue-acts.xml  Bns003.C.dialogue-acts.xml
# Bed014.C.dialogue-acts.xml  Bns003.D.dialogue-acts.xml
# Bed014.D.dialogue-acts.xml  Bns003.E.dialogue-acts.xml
# Bed014.E.dialogue-acts.xml  Bns003.F.dialogue-acts.xml
# Bed014.F.dialogue-acts.xml  Bro003.A.dialogue-acts.xml
# Bed015.A.dialogue-acts.xml  Bro003.B.dialogue-acts.xml
# Bed015.B.dialogue-acts.xml  Bro003.C.dialogue-acts.xml
# Bed015.C.dialogue-acts.xml  Bro003.D.dialogue-acts.xml
# Bed015.D.dialogue-acts.xml  Bro003.E.dialogue-acts.xml
# Bed015.E.dialogue-acts.xml  Bro003.F.dialogue-acts.xml
# Bmr019.D.dialogue-acts.xml  Bro027.C.dialogue-acts.xml
# Bmr019.E.dialogue-acts.xml  Bro027.D.dialogue-acts.xml
# Bmr019.F.dialogue-acts.xml  Bro028.A.dialogue-acts.xml
# Bmr019.G.dialogue-acts.xml  Bro028.B.dialogue-acts.xml
# Bmr019.H.dialogue-acts.xml  Bro028.C.dialogue-acts.xml
# Bmr019.I.dialogue-acts.xml  Bro028.D.dialogue-acts.xml
# Bmr020.A.dialogue-acts.xml  Bro028.E.dialogue-acts.xml
# Bmr020.B.dialogue-acts.xml  Bsr001.A.dialogue-acts.xml
# Bmr020.C.dialogue-acts.xml  Bsr001.B.dialogue-acts.xml
# Bmr020.D.dialogue-acts.xml  Bsr001.C.dialogue-acts.xml
# Bmr020.E.dialogue-acts.xml  Bsr001.D.dialogue-acts.xml
# Bmr020.F.dialogue-acts.xml  Bsr001.E.dialogue-acts.xml
# Bmr020.G.dialogue-acts.xml  Bsr001.F.dialogue-acts.xml
# Bmr021.A.dialogue-acts.xml  Bsr001.G.dialogue-acts.xml
# Bmr021.B.dialogue-acts.xml  Bsr001.H.dialogue-acts.xml
# Bmr021.C.dialogue-acts.xml  Btr001.A.dialogue-acts.xml
# Bmr021.D.dialogue-acts.xml  Btr001.B.dialogue-acts.xml
# Bmr021.E.dialogue-acts.xml  Btr001.C.dialogue-acts.xml
# Bmr021.F.dialogue-acts.xml  Btr001.D.dialogue-acts.xml
# Bmr022.A.dialogue-acts.xml  Btr001.E.dialogue-acts.xml
# Bmr022.B.dialogue-acts.xml  Btr001.F.dialogue-acts.xml
# Bmr022.C.dialogue-acts.xml  Btr002.A.dialogue-acts.xml
# Bmr022.D.dialogue-acts.xml  Btr002.B.dialogue-acts.xml
# Bmr022.E.dialogue-acts.xml  Btr002.C.dialogue-acts.xml
# Bmr022.F.dialogue-acts.xml  Btr002.D.dialogue-acts.xml
# Bmr023.A.dialogue-acts.xml  Btr002.E.dialogue-acts.xml
# Bmr023.B.dialogue-acts.xml  Btr002.F.dialogue-acts.xml
# Bmr023.C.dialogue-acts.xml  Buw001.A.dialogue-acts.xml
# Bmr023.D.dialogue-acts.xml  Buw001.B.dialogue-acts.xml
# Bmr023.E.dialogue-acts.xml  Buw001.C.dialogue-acts.xml
# Bmr023.F.dialogue-acts.xml  Buw001.D.dialogue-acts.xml
# Bmr023.G.dialogue-acts.xml  Buw001.E.dialogue-acts.xml
# Bmr024.A.dialogue-acts.xml  Buw001.F.dialogue-acts.xml
# Bmr024.B.dialogue-acts.xml  Buw001.G.dialogue-acts.xml
# Bmr024.C.dialogue-acts.xml  Buw001.H.dialogue-acts.xml
# Bmr024.D.dialogue-acts.xml

# %%
import pandas as pd
import xml.etree.ElementTree as et
import os
from pathlib import Path
import glob

# %%
with os.scandir('/content/drive/My Drive/Team 6/xml-audio') as entries:
    for entry in entries:
        print(entry.name)
# Out:
# Bmr023.D.dialogue-acts.xml
# Bmr030.D.dialogue-acts.xml
# Bmr030.E.dialogue-acts.xml
# Bmr022.E.dialogue-acts.xml
# Bro024.E.dialogue-acts.xml
# Bmr023.G.dialogue-acts.xml
# Bed011.B.dialogue-acts.xml
# Bro017.B.dialogue-acts.xml
# Bmr011.G.dialogue-acts.xml
# Bro027.D.dialogue-acts.xml
# Bro011.E.dialogue-acts.xml
# Bro022.A.dialogue-acts.xml
# Bed014.F.dialogue-acts.xml
# Bmr029.A.dialogue-acts.xml
# Bmr020.G.dialogue-acts.xml
# Bro007.D.dialogue-acts.xml
# Bsr001.H.dialogue-acts.xml
# Bro015.F.dialogue-acts.xml
# Bmr014.A.dialogue-acts.xml
# Bro011.B.dialogue-acts.xml
# Bmr008.C.dialogue-acts.xml
# Bmr027.B.dialogue-acts.xml
# Bro003.F.dialogue-acts.xml
# Bns003.C.dialogue-acts.xml
# Bmr016.G.dialogue-acts.xml
# Bmr005.D.dialogue-acts.xml
# Bmr011.A.dialogue-acts.xml
# Bed002.A.dialogue-acts.xml
# Bed004.B.dialogue-acts.xml
# Bmr025.F.dialogue-acts.xml
# Bed012.D.dialogue-acts.xml
# Bro026.A.dialogue-acts.xml
# Bmr001.A.dialogue-acts.xml
# Bmr011.H.dialogue-acts.xml
# Bmr008.F.dialogue-acts.xml
# Bmr015.F.dialogue-acts.xml
# Bmr031.D.dialogue-acts.xml
# Bro010.E.dialogue-acts.xml
# Bmr003.A.dialogue-acts.xml
# Bmr022.C.dialogue-acts.xml
# Bro004.C.dialogue-acts.xml
# Bmr018.E.dialogue-acts.xml
# Bed010.C.dialogue-acts.xml
# Bmr027.G.dialogue-acts.xml
# Bmr014.D.dialogue-acts.xml
# Buw001.A.dialogue-acts.xml
# Bmr026.F.dialogue-acts.xml
# Bmr007.C.dialogue-acts.xml
# Bro023.C.dialogue-acts.xml
# Bed014.D.dialogue-acts.xml
# Bmr015.B.dialogue-acts.xml
# Bmr021.D.dialogue-acts.xml
# Bro015.B.dialogue-acts.xml
# Bro022.C.dialogue-acts.xml
# Bed014.C.dialogue-acts.xml
# Bro012.D.dialogue-acts.xml
# Bed006.E.dialogue-acts.xml
# Bmr019.A.dialogue-acts.xml
# Bro028.E.dialogue-acts.xml
# Bsr001.G.dialogue-acts.xml
# Bro014.F.dialogue-acts.xml
# Bro011.F.dialogue-acts.xml
# Bmr003.D.dialogue-acts.xml
# Bro019.E.dialogue-acts.xml
# Bdb001.B.dialogue-acts.xml
# Bed009.C.dialogue-acts.xml
# Bmr031.F.dialogue-acts.xml
# Bro003.B.dialogue-acts.xml
# Bro018.E.dialogue-acts.xml
# Bns003.D.dialogue-acts.xml
# Bed003.D.dialogue-acts.xml
# Bro013.C.dialogue-acts.xml
# Bed002.E.dialogue-acts.xml
# Bro007.B.dialogue-acts.xml
# Bmr002.D.dialogue-acts.xml
# Bmr021.F.dialogue-acts.xml
# Bmr028.A.dialogue-acts.xml
# Bns001.F.dialogue-acts.xml
# Bed003.C.dialogue-acts.xml
# Bmr010.G.dialogue-acts.xml
# Bmr009.D.dialogue-acts.xml
# Bmr008.B.dialogue-acts.xml
# Bmr016.F.dialogue-acts.xml
# Bro024.G.dialogue-acts.xml
# Btr002.E.dialogue-acts.xml
# Bmr024.F.dialogue-acts.xml
# Bmr025.B.dialogue-acts.xml
# Bro004.E.dialogue-acts.xml
# Bro010.D.dialogue-acts.xml
# Bro003.D.dialogue-acts.xml
# Bro003.C.dialogue-acts.xml
# Bmr020.B.dialogue-acts.xml
# Bro023.B.dialogue-acts.xml
# Bmr016.A.dialogue-acts.xml
# Bro024.H.dialogue-acts.xml
# Bro021.D.dialogue-acts.xml
# Bmr012.D.dialogue-acts.xml
# Bns002.D.dialogue-acts.xml
# Bmr013.G.dialogue-acts.xml
# Bmr025.E.dialogue-acts.xml
# Bmr028.H.dialogue-acts.xml
# Bmr021.B.dialogue-acts.xml
# Bns003.F.dialogue-acts.xml
# Bro018.C.dialogue-acts.xml
# Bns003.A.dialogue-acts.xml
# Btr001.F.dialogue-acts.xml
# Bmr010.C.dialogue-acts.xml
# Bro023.D.dialogue-acts.xml
# Bro025.E.dialogue-acts.xml
# Bed017.C.dialogue-acts.xml
# Bmr018.B.dialogue-acts.xml
# Bns001.E.dialogue-acts.xml
# Bmr019.B.dialogue-acts.xml
# Bed013.A.dialogue-acts.xml
# Bro015.E.dialogue-acts.xml
# Bdb001.D.dialogue-acts.xml
# Bro008.B.dialogue-acts.xml
# Bed011.C.dialogue-acts.xml
# Bed006.D.dialogue-acts.xml
# Bro027.A.dialogue-acts.xml
# Bed004.A.dialogue-acts.xml
# Bsr001.B.dialogue-acts.xml
# Bns002.B.dialogue-acts.xml
# Bed017.D.dialogue-acts.xml
# Bmr009.B.dialogue-acts.xml
# Bro025.B.dialogue-acts.xml
# Bmr002.C.dialogue-acts.xml
# Bro014.B.dialogue-acts.xml
# Bed009.A.dialogue-acts.xml
# Bmr014.C.dialogue-acts.xml
# Bmr013.A.dialogue-acts.xml
# Bns001.G.dialogue-acts.xml
# Bro019.B.dialogue-acts.xml
# Bro024.F.dialogue-acts.xml
# Bed013.C.dialogue-acts.xml
# Bro027.B.dialogue-acts.xml
# Bmr005.B.dialogue-acts.xml
# Bed009.D.dialogue-acts.xml
# Bmr031.B.dialogue-acts.xml
# Bed013.B.dialogue-acts.xml
# Bro004.G.dialogue-acts.xml
# Bro022.G.dialogue-acts.xml
# Bmr021.C.dialogue-acts.xml
# Bsr001.F.dialogue-acts.xml
# Bmr015.E.dialogue-acts.xml
# Bro008.E.dialogue-acts.xml
# Bmr012.J.dialogue-acts.xml
# Bed004.D.dialogue-acts.xml
# Bmr031.H.dialogue-acts.xml
# Bro022.E.dialogue-acts.xml
# Bro012.F.dialogue-acts.xml
# Bmr011.D.dialogue-acts.xml
# Bmr002.A.dialogue-acts.xml
# Bro021.A.dialogue-acts.xml
# Bmr027.F.dialogue-acts.xml
# Bed013.E.dialogue-acts.xml
# Bmr029.E.dialogue-acts.xml
# Bmr023.C.dialogue-acts.xml
# Bro004.D.dialogue-acts.xml
# Bed006.C.dialogue-acts.xml
# Bmr006.C.dialogue-acts.xml
# Bsr001.C.dialogue-acts.xml
# Bro025.A.dialogue-acts.xml
# Bro022.D.dialogue-acts.xml
# Bro003.G.dialogue-acts.xml
# Btr001.A.dialogue-acts.xml
# Bmr026.B.dialogue-acts.xml
# Bro016.D.dialogue-acts.xml
# Bed011.F.dialogue-acts.xml
# Buw001.C.dialogue-acts.xml
# Bmr022.F.dialogue-acts.xml
# Bed009.F.dialogue-acts.xml
# Bmr024.H.dialogue-acts.xml
# Bmr023.B.dialogue-acts.xml
# Bed004.C.dialogue-acts.xml
# Bmr026.A.dialogue-acts.xml
# Bmr012.E.dialogue-acts.xml
# Buw001.B.dialogue-acts.xml
# Bro011.A.dialogue-acts.xml
# Bmr029.F.dialogue-acts.xml
# Bro014.A.dialogue-acts.xml
# Bro014.D.dialogue-acts.xml
# Bro008.A.dialogue-acts.xml
# Bro019.D.dialogue-acts.xml
# Bmr022.B.dialogue-acts.xml
# Bmr023.E.dialogue-acts.xml
# Bro027.C.dialogue-acts.xml
# Bmr019.F.dialogue-acts.xml
# Bmr003.C.dialogue-acts.xml
# Bmr031.G.dialogue-acts.xml
# Bro016.C.dialogue-acts.xml
# Bmr022.A.dialogue-acts.xml
# Bmr006.E.dialogue-acts.xml
# Bed002.D.dialogue-acts.xml
# Bmr014.B.dialogue-acts.xml
# Bed015.B.dialogue-acts.xml
# Bmr023.A.dialogue-acts.xml
# Bmr005.F.dialogue-acts.xml
# Bmr020.A.dialogue-acts.xml
# Bmr007.D.dialogue-acts.xml
# Bro010.A.dialogue-acts.xml
# Bmr027.H.dialogue-acts.xml
# Bmr006.F.dialogue-acts.xml
# Bed005.A.dialogue-acts.xml
# Bro026.E.dialogue-acts.xml
# Bmr028.F.dialogue-acts.xml
# Bro005.B.dialogue-acts.xml
# Bro021.C.dialogue-acts.xml
# Bmr019.I.dialogue-acts.xml
# Bmr012.F.dialogue-acts.xml
# Bed006.B.dialogue-acts.xml
# Bsr001.A.dialogue-acts.xml
# Bed008.C.dialogue-acts.xml
# Bro010.B.dialogue-acts.xml
# Bed005.B.dialogue-acts.xml
# Bed002.B.dialogue-acts.xml
# Bro013.A.dialogue-acts.xml
# Buw001.F.dialogue-acts.xml
# Bmr024.B.dialogue-acts.xml
# Bro012.A.dialogue-acts.xml
# Bro023.A.dialogue-acts.xml
# Btr002.D.dialogue-acts.xml
# Bro028.C.dialogue-acts.xml
# Btr002.A.dialogue-acts.xml
# Bro005.A.dialogue-acts.xml
# Bmr022.D.dialogue-acts.xml
# Bro026.D.dialogue-acts.xml
# Bns001.B.dialogue-acts.xml
# Bmr008.E.dialogue-acts.xml
# Bdb001.A.dialogue-acts.xml
# Bmr005.A.dialogue-acts.xml

# %%
#to make sure colab reads the correct files
print(glob.glob("/content/drive/My Drive/xml-audio/*.xml"))
# Out:
# []

# %%
#def getvalueofnode(node):
    #""" return node text or None """
    #return node.text if node is not None else None

def main():
    """ main """
    filenames =  glob.glob("/content/drive/My Drive/Team 6/xml-audio/Bdb001.A.dialogue-acts.xml") 
    filename = [] 
    li = []
    for filename in filenames :
         
         global left
         parsed_xml = et.parse(filename)
         #I hard-coded here but i think it would be easier to modify the panda dataframe later
         dfcols = ['Id', 'st_time', 'ed_time', 'type', 'adjacency', 'original-type', 'channel', 'participant']
         left = pd.DataFrame(columns=dfcols)

         root = parsed_xml.getroot()
         
        
         for diaAct in parsed_xml.findall('./dialogueact'):
             uId = diaAct.get('{http://nite.sourceforge.net/}id')
             sT = diaAct.get("starttime")
             eT = diaAct.get("endtime")
             tP = diaAct.get("type")
             aJ = diaAct.get("adjacency")
             oT = diaAct.get("original-type")
             ch = diaAct.get("channel")
             par = diaAct.get("participant")

             
             left = left.append(pd.Series([uId, sT, eT, tP, aJ, oT, ch, par], index=dfcols),ignore_index=True)
             li.append(left)
             
    left = pd.concat(li, axis=0, ignore_index=True)

    return left

left = main()

left.head(5)
# Out:
#                        Id  st_time  ed_time    type adjacency original-type  \
# 0  Bdb001.A.dialogueact74  164.014  165.974  s^bk|s     5b.6a        s^bk|s
# 1  Bdb001.A.dialogueact74  164.014  165.974  s^bk|s     5b.6a        s^bk|s
# 2  Bdb001.A.dialogueact78  165.974  166.184    s^bk       5b+          s^bk
# 3  Bdb001.A.dialogueact74  164.014  165.974  s^bk|s     5b.6a        s^bk|s
# 4  Bdb001.A.dialogueact78  165.974  166.184    s^bk       5b+          s^bk
#
#   channel participant
# 0      c1       mn017
# 1      c1       mn017
# 2      c1       mn017
# 3      c1       mn017
# 4      c1       mn017

# %% [markdown]
# ## Preprocessing

# %%
df = left #.loc[1:500]
df = df.drop_duplicates(keep='first')

# Add the 'Interruption' (bool) variable
df['Interruption'] = df['type'].str.contains('%-', regex = False)
df['Interruption'] = df['Interruption'].astype(bool)

# View what types are counted as Interruptions 
# print(df.loc[df['Interruption'], 'type'])
# Out:
# 27      s^bk.%-
# 65        s.%--
# 90           %-
# 104          %-
# 170       s.%--
# 189        s.%-
# 252          %-
# 299    s^cs.%--
# 495       s.%--
# Name: type, dtype: object
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# Add segment length variable
df.loc[:, 'st_time'] = pd.to_numeric(df.loc[:, 'st_time'])
df.loc[:, 'ed_time'] = pd.to_numeric(df.loc[:, 'ed_time'])
df.loc[:, 'length'] = df.ed_time - df.st_time

segment_length = df.length.max()

# %%
import numpy as np

# Dummy segments dataframe
segments_df = pd.DataFrame(np.zeros((100, 3)))
segments_df.columns = ['id', 'st_time', 'ed_time']

def getLabel(segments, interruptions):
    counts = np.empty(segments.shape[0])

    for seg_index, seg_row in segments.iterrows():
      for inter_index, inter_row in interruptions.iterrows():
        if seg_row['st_time'] < inter_row['st_time'] and seg_row['ed_time'] > inter_row['ed_time']:
          counts[seg_index] += 1
        else:
          counts[seg_index] = 0

    # label as True if there's at least one entire interruption in the segment
    labels = counts > 0 
    return labels

labels = getLabel(segments_df, df)
